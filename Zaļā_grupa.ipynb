# %% [markdown]
# <a href="https://colab.research.google.com/github/NewBieWhoLearnCSharp/ZG_1/blob/main/Za%C4%BC%C4%81_grupa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-240-g84ec8b5 Python-3.10.12 torch-2.1.0+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.1/107.7 GB disk)

# %%
# !unzip /content/train_data.zip -d /content/train_data
# Out:
# Archive:  /content/train_data.zip
#    creating: /content/train_data/train data/
#    creating: /content/train_data/train data/images/
#    creating: /content/train_data/train data/images/train/
#   inflating: /content/train_data/train data/images/train/1.jpg
#   inflating: /content/train_data/train data/images/train/10.jpg
#   inflating: /content/train_data/train data/images/train/11.jpg
#   inflating: /content/train_data/train data/images/train/12.jpg
#   inflating: /content/train_data/train data/images/train/13.jpg
#   inflating: /content/train_data/train data/images/train/14.jpg
#   inflating: /content/train_data/train data/images/train/15.jpg
#   inflating: /content/train_data/train data/images/train/16.jpg
#   inflating: /content/train_data/train data/images/train/17.jpg
#   inflating: /content/train_data/train data/images/train/18.jpeg
#   inflating: /content/train_data/train data/images/train/19.jpeg
#   inflating: /content/train_data/train data/images/train/2.jpeg
# ...

# %%
# Train YOLOv5s on COCO128 for 75 epochs
# !python train.py --img 640 --batch 16 --epochs 100 --data /content/yolov5/data/coco128_tests.yaml --weights yolov5s.pt --cache
# Out:
# 2023-11-11 06:36:59.116005: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-11 06:36:59.116165: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-11 06:36:59.116395: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/last.pt --img 640 --conf 0.25 --source /content/test_5.jpeg
# Out:
# detect: weights=['runs/train/exp2/weights/last.pt'], source=/content/test_5.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-240-g84ec8b5 Python-3.10.12 torch-2.1.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7029004 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/test_5.jpeg: 640x480 (no detections), 343.8ms
# Speed: 2.9ms pre-process, 343.8ms inference, 0.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp7
